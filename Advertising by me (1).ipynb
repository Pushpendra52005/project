# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("Advertising.csv",index_col=0)
df
# Out:
#         TV  radio  newspaper  sales
# 1    230.1   37.8       69.2   22.1
# 2     44.5   39.3       45.1   10.4
# 3     17.2   45.9       69.3    9.3
# 4    151.5   41.3       58.5   18.5
# 5    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 196   38.2    3.7       13.8    7.6
# 197   94.2    4.9        8.1    9.7
# 198  177.0    9.3        6.4   12.8
# 199  283.6   42.0       66.2   25.5
# 200  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
df.corr()
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000

# %%
df.head(10)
# Out:
#        TV  radio  newspaper  sales
# 1   230.1   37.8       69.2   22.1
# 2    44.5   39.3       45.1   10.4
# 3    17.2   45.9       69.3    9.3
# 4   151.5   41.3       58.5   18.5
# 5   180.8   10.8       58.4   12.9
# 6     8.7   48.9       75.0    7.2
# 7    57.5   32.8       23.5   11.8
# 8   120.2   19.6       11.6   13.2
# 9     8.6    2.1        1.0    4.8
# 10  199.8    2.6       21.2   10.6

# %%
df.tail()
# Out:
#         TV  radio  newspaper  sales
# 196   38.2    3.7       13.8    7.6
# 197   94.2    4.9        8.1    9.7
# 198  177.0    9.3        6.4   12.8
# 199  283.6   42.0       66.2   25.5
# 200  232.1    8.6        8.7   13.4

# %%
df.tail(10)
# Out:
#         TV  radio  newspaper  sales
# 191   39.5   41.1        5.8   10.8
# 192   75.5   10.8        6.0    9.9
# 193   17.2    4.1       31.6    5.9
# 194  166.8   42.0        3.6   19.6
# 195  149.7   35.6        6.0   17.3
# 196   38.2    3.7       13.8    7.6
# 197   94.2    4.9        8.1    9.7
# 198  177.0    9.3        6.4   12.8
# 199  283.6   42.0       66.2   25.5
# 200  232.1    8.6        8.7   13.4

# %%
df.isnull().sum()
# Out:
# TV           0
# radio        0
# newspaper    0
# sales        0
# dtype: int64

# %%
df.shape
# Out:
# (200, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 200 entries, 1 to 200
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   radio      200 non-null    float64
#  2   newspaper  200 non-null    float64
#  3   sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 7.8 KB

# %%
df.std()
# Out:
# TV           85.854236
# radio        14.846809
# newspaper    21.778621
# sales         5.217457
# dtype: float64

# %%
df.mean()
# Out:
# TV           147.0425
# radio         23.2640
# newspaper     30.5540
# sales         14.0225
# dtype: float64

# %%
df.median()
# Out:
# TV           149.75
# radio         22.90
# newspaper     25.75
# sales         12.90
# dtype: float64

# %%
df.mode().sum()
# Out:
# TV           1662.6
# radio           9.8
# newspaper      43.6
# sales           9.7
# dtype: float64

# %%
df.describe()
# Out:
#                TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
df.mean(axis=0)
# Out:
# TV           147.0425
# radio         23.2640
# newspaper     30.5540
# sales         14.0225
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# 1       89.800
# 2       34.825
# 3       35.425
# 4       67.450
# 5       65.725
#         ...
# 196     15.825
# 197     29.225
# 198     51.375
# 199    104.325
# 200     65.700
# Length: 200, dtype: float64

# %%
df.isna().sum()
# Out:
# TV           0
# radio        0
# newspaper    0
# sales        0
# dtype: int64

# %%
df.dtypes
# Out:
# TV           float64
# radio        float64
# newspaper    float64
# sales        float64
# dtype: object

# %%
correlation=df.corr()

sns.heatmap(correlation,annot=True)
# Out:
# <Axes: >

# %%
df.corr()
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000

# %%
correlation = df.corr()
plt.figure(figsize=(8,6))
sns.heatmap(correlation, cmap='viridis', annot=True, fmt=".2f")
plt.show()
df.corr()
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000

# %%
df.hist(figsize=(8,6))
# Out:
# array([[<Axes: title={'center': 'TV'}>,
#         <Axes: title={'center': 'radio'}>],
#        [<Axes: title={'center': 'newspaper'}>,
#         <Axes: title={'center': 'sales'}>]], dtype=object)

# %%
from pandas.plotting import scatter_matrix
attch=["TV","radio","newspaper"]
scatter_matrix(df[attch],figsize=(12,8))
# Out:
# array([[<Axes: xlabel='TV', ylabel='TV'>,
#         <Axes: xlabel='radio', ylabel='TV'>,
#         <Axes: xlabel='newspaper', ylabel='TV'>],
#        [<Axes: xlabel='TV', ylabel='radio'>,
#         <Axes: xlabel='radio', ylabel='radio'>,
#         <Axes: xlabel='newspaper', ylabel='radio'>],
#        [<Axes: xlabel='TV', ylabel='newspaper'>,
#         <Axes: xlabel='radio', ylabel='newspaper'>,
#         <Axes: xlabel='newspaper', ylabel='newspaper'>]], dtype=object)

# %%
sns.barplot(df)
# Out:
# <Axes: >

# %%
df1=pd.DataFrame(df)
sns.boxplot(df1)



# Show the plot
plt.show()

# %%
df.shape
# Out:
# (200, 4)

# %%
print(df.shape)
Q1=np.percentile(df["newspaper"],25)
Q3=np.percentile(df["newspaper"],75)
outlier_lower=Q1-1.5*(Q3-Q1)
outlier_high=Q3+1.5*(Q3-Q1)
df=df[(df["newspaper"]>outlier_lower )&(df["newspaper"]<outlier_high)]
print(df.shape)
# Out:
# (200, 4)
# (198, 4)

# %%
df1=pd.DataFrame(df)
sns.boxplot(df1)



# Show the plot
plt.show()

# %%
df.groupby(df["newspaper"]).median()
# Out:
#               TV  radio  sales
# newspaper
# 0.3        265.6   20.0   17.4
# 0.9         69.0    9.3    9.3
# 1.0          8.6    2.1    4.8
# 1.7        184.9   43.9   20.7
# 1.8        293.6   27.7   20.7
# ...          ...    ...    ...
# 79.2       125.7   36.9   15.9
# 84.8       234.5    3.4   11.9
# 89.4        16.9   43.7    8.7
# 100.9      296.4   36.3   23.8
# 114.0       67.8   36.6   12.5
#
# [172 rows x 3 columns]

# %%
sns.histplot(data=df,x="TV",kde=True)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='TV', ylabel='Count'>

# %%
sns.histplot(data=df,x="newspaper",kde=True)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='newspaper', ylabel='Count'>

# %%
sns.histplot(data=df,x="radio",kde=True)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='radio', ylabel='Count'>

# %%
sns.histplot(data=df,x="TV",y="newspaper",kde=True)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='TV', ylabel='newspaper'>

# %%
sns.histplot(data=df,x="TV",y="radio",kde=True,)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='TV', ylabel='radio'>

# %%
dir(sns)
# Out:
# ['FacetGrid',
#  'JointGrid',
#  'PairGrid',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_compat',
#  '_core',
#  '_decorators',
#  '_docstrings',
#  '_oldcore',
#  '_orig_rc_params',
#  '_statistics',
#  '_stats',
#  'algorithms',
#  'axes_style',
#  'axisgrid',
#  'barplot',
#  'blend_palette',
#  'boxenplot',
#  'boxplot',
#  'categorical',
#  'catplot',
#  'choose_colorbrewer_palette',
#  'choose_cubehelix_palette',
#  'choose_dark_palette',
#  'choose_diverging_palette',
#  'choose_light_palette',
#  'clustermap',
#  'cm',
#  'color_palette',
#  'colors',
#  'countplot',
#  'crayon_palette',
#  'crayons',
#  'cubehelix_palette',
#  'dark_palette',
#  'desaturate',
#  'despine',
#  'displot',
#  'distplot',
#  'distributions',
#  'diverging_palette',
#  'dogplot',
#  'ecdfplot',
#  'external',
#  'get_data_home',
#  'get_dataset_names',
#  'heatmap',
# ...

# %%
sns.jointplot(data=df,x="TV",y="sales")
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.jointplot(data=df,x="radio",y="sales")
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.jointplot(data=df,x="newspaper",y="sales")
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.lmplot(data=df,x="TV",y="sales")

# %%
sns.lmplot(data=df,x="radio",y="sales")

# %%
sns.lmplot(data=df,x="newspaper",y="sales")

# %%
sns.countplot(df)
# Out:
# <Axes: ylabel='count'>

# %%
sns.displot(df["TV"])
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.pairplot(df)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
df.sample(10)
# Out:
#         TV  radio  newspaper  sales
# 154  171.3   39.7       37.7   19.0
# 8    120.2   19.6       11.6   13.2
# 122   18.8   21.7       50.4    7.0
# 101  222.4    4.3       49.8   11.7
# 51   199.8    3.1       34.6   11.4
# 70   216.8   43.9       27.2   22.3
# 119  125.7   36.9       79.2   15.9
# 64   102.7   29.6        8.4   14.0
# 1    230.1   37.8       69.2   22.1
# 27   142.9   29.3       12.6   15.0

# %% [markdown]
# # Training and Testing

# %%
feature_cols = ['TV'] # since we are doing simple linear regression, I have taken only one feature
X = df[feature_cols]
y = df.sales

# %%
y
# Out:
# 1      22.1
# 2      10.4
# 3       9.3
# 4      18.5
# 5      12.9
#        ...
# 196     7.6
# 197     9.7
# 198    12.8
# 199    25.5
# 200    13.4
# Name: sales, Length: 200, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 200 entries, 1 to 200
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   radio      200 non-null    float64
#  2   newspaper  200 non-null    float64
#  3   sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 7.8 KB

# %%
# Train-test split 
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
print(f"Shape of X_train is {X_train.shape}")
print(f"Shape of y_train is {y_train.shape}")
print(f"Shape of X_test is {X_test.shape}")
print(f"Shape of y_test is {y_test.shape}")
# Out:
# Shape of X_train is (140, 1)
# Shape of y_train is (140,)
# Shape of X_test is (60, 1)
# Shape of y_test is (60,)

# %%
X_train
# Out:
#         TV
# 170  284.3
# 98   184.9
# 32   112.9
# 13    23.8
# 36   290.7
# ..     ...
# 107   25.0
# 15   204.1
# 93   217.7
# 180  165.6
# 103  280.2
#
# [140 rows x 1 columns]

# %% [markdown]
# Fitting the model to our training data

# %%
from sklearn.linear_model import LinearRegression
lm =  LinearRegression()
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Checking the intercept and coefficient

# %%
print(f"The intercept is {lm.intercept_}") # Gives the intercept
print(f"The coefficient is {lm.coef_}") # Gives the coefficient
# Out:
# The intercept is 7.239459830751143
# The coefficient is [0.0464078]

# %%
df=pd.read_csv("Advertising.csv",index_col=0)
df.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
preds_train = lm.predict(X_train)
preds_train
# Out:
# array([20.43319798, 15.82026244, 12.47890069,  8.34396552, 20.73020791,
#         8.13977119, 20.86479054,  8.10728573, 13.47202766,  8.42749957,
#        11.89880316, 10.96136556, 15.98268975, 15.45364081, 13.07292056,
#        16.96653516, 13.87113475, 15.82026244, 17.56055502, 18.45622561,
#         8.03767403, 12.83159999, 11.40223968, 16.10799082, 10.74324889,
#        16.2054472 , 11.21660847, 19.62570222,  9.07256801, 19.36581853,
#         7.85204282, 16.2286511 , 20.99473238, 19.56537208, 17.20321495,
#        14.18670781, 13.35136737,  9.90790845, 18.38197312, 13.79688227,
#        15.62999046, 11.7502982 , 17.4723802 , 13.75047447, 19.09201249,
#        11.7038904 , 10.30701555, 18.34484688, 15.39331066, 18.38197312,
#         8.07015949, 17.9178951 , 20.40071251, 15.18911634, 16.47925323,
#        12.95226027, 13.32352269,  8.40429566, 14.82713548, 18.785721  ,
#        16.63703976,  7.84740204,  7.42973182, 11.59715245, 19.44007101,
# ...

# %%
preds_test = lm.predict(X_test)
preds_test
# Out:
# array([14.81785392, 16.30754437, 20.83230507,  7.78243112, 17.46309864,
#        10.72468577, 17.30067133,  9.55984994, 17.56055502, 15.36546598,
#         8.7013056 ,  9.84757831, 18.12208943,  7.49006196, 13.71334823,
#        15.13806775,  7.57823679, 16.40964153, 10.73396733, 18.25667206,
#        17.89005042, 10.38590882,  9.00295631, 18.88317738, 10.44159818,
#         9.72227724, 17.14752559, 13.70406667, 11.28622018,  7.62928537,
#        16.5117387 , 10.45087974, 16.46997167,  8.02375169, 20.26612989,
#        18.2937983 ,  9.48095667, 19.94127527, 12.67845424,  8.51567439,
#        12.62276488, 15.45364081,  9.2396361 , 10.1306659 , 17.63480751,
#         9.01223787, 10.51585066, 14.07532908, 12.09371593, 10.78037513,
#        10.86854996, 15.05453371,  7.64320771,  7.60144069, 10.78501591,
#        13.24462943, 10.64579251, 20.68380011,  8.14905275, 16.40964153])

# %% [markdown]
# # Standardizing the dataset
#
# In Python's scikit-learn library, the StandardScaler module is used for scaling features to zero mean and unit variance. This process is commonly known as standardization and is a critical step in data preprocessing, especially for machine learning algorithms that are sensitive to the scale of input features, like Support Vector Machines (SVMs) and neural networks.
#
# **standardscaler is part of preprocessing**
#
# **How StandardScaler Works**:Fit computes the mean (μ) and standard deviation (σ) for each feature in the training dataset.
# Transform: Scale each feature (x) in the dataset to z=(𝑥−𝜇)𝜎z= σ(x−μ)
# ​, where x is a feature value, μ is the mean of the feature, and σ is the standard deviation of the feature. This transformation changes the distribution of the feature to have a mean of zero and a standard deviation of one.
# Example:
# Consider a dataset with one feature having values [1, 2, 3]. Here’s how StandardScaler would standardize the data:
#
# Mean (μ) = (1+2+3)/3 = 2
# Standard Deviation (σ) = sqrt([(1-2)^2 + (2-2)^2 + (3-2)^2]/3) = 1
# Standardized data = [(1-2)/1, (2-2)/1, (3-2)/1] = [-1, 0, 1]
# By standardizing features, you ensure that the model treats all features equally, especially in terms of their scale, improving the performance and stability of the learning algorithm.
#
# The standard scaler is a preprocessing technique used in data analysis and machine learning to standardize the features of a dataset. It transforms the data so that it has a mean of zero and a standard deviation of one. This is particularly useful for algorithms that are sensitive to the scale of the data, such as support vector machines, k-nearest neighbors, and gradient descent-based methods.
#
# *Use of Standard Scaler:*
# 1. *Normalization:* Standard scaling ensures that all features contribute equally to the analysis, preventing features with larger scales from dominating those with smaller scales.
# 2. *Improving convergence:* For optimization algorithms like gradient descent, standard scaling can significantly improve the convergence speed by providing a well-scaled input space.
# 3. *Consistent Results:* It helps achieve more consistent and reliable results across different machine learning algorithms.
#
# *Examples of When to Use Standard Scaler:*
# 1. *Linear Regression:*
#    - When applying linear regression, the scaling of features can impact the performance of the model. By standardizing the data, you can ensure that the coefficients learned are proportional to the standardized features, leading to more interpretable and reliable models.
#
# 2. *Principal Component Analysis (PCA):*
#    - PCA aims to reduce the dimensionality of data by projecting it onto the principal components. Standard scaling is crucial here as it ensures that all features contribute equally to the principal components, avoiding the dominance of features with larger variances.
#
# 3. *Support Vector Machines (SVM):*
#    - SVMs are sensitive to the scale of the input features. Standardizing the data ensures that all features are on the same scale, which can lead to better decision boundaries and improved classification performance.
#
# 4. *Clustering Algorithms (e.g., K-means):*
#    - In clustering algorithms, the distance between data points is a critical factor. Standardizing features ensures that each feature contributes equally to the distance calculations, resulting in more meaningful clusters.

# %%
from sklearn.metrics import r2_score,mean_squared_error
print(f"RMSE for train data is : {np.sqrt(mean_squared_error(y_train,preds_train))}")
print(f"R2 for train data is {r2_score(y_train,preds_train)}")
print(f"RMSE for test data is : {np.sqrt(mean_squared_error(y_test,preds_test))}")
print(f"R2 for test data is {r2_score(y_test,preds_test)}")
# Out:
# RMSE for train data is : 3.3450117024237263
# R2 for train data is 0.5736021199591975
# RMSE for test data is : 2.995161304907236
# R2 for test data is 0.6714477229302764

# %%
sns.regplot(x=np.reshape(X_train,newshape=(140,)),y=np.reshape(y_train,newshape=(140,)))
plt.xlabel("TV")
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %%
sns.regplot(x=np.reshape(X_train,newshape=(140,)),y=np.reshape(y_train,newshape=(140,)))
plt.xlabel("TV")
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %%
lm.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %% [markdown]
#  # Simple Linear Regression using statsmodels

# %%
import statsmodels.api as sm
x_train = sm.add_constant(X_train)  # This gives the intercept
model = sm.OLS(y_train,x_train).fit()

# %%
model

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.574
# Model:                            OLS   Adj. R-squared:                  0.571
# Method:                 Least Squares   F-statistic:                     185.6
# Date:                Tue, 21 May 2024   Prob (F-statistic):           2.55e-27
# Time:                        08:51:07   Log-Likelihood:                -367.70
# No. Observations:                 140   AIC:                             739.4
# Df Residuals:                     138   BIC:                             745.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          7.2395      0.604     11.986      0.000       6.045       8.434
# ...

# %% [markdown]
# # Multiple Linear Regression¶
#
#
#
#
#
#
# Using multiple linear regression

# %%
feature_cols = ['TV','radio','newspaper']
x = df[feature_cols]
y = df.sales

# %% [markdown]
# Train-test split

# %%
from sklearn import model_selection as ms
xtrain,xtest,ytrain,ytest = ms.train_test_split(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

# Suppose we have the following dataset
data = np.array([[50, 2], [60, 4], [70, 6], [80, 8]])

# Initialize the StandardScaler
scaler = StandardScaler()

# Fit the scaler to the data - this calculates the mean and standard deviation
scaler.fit(data)

# See the mean and standard deviation
print("Mean:", scaler.mean_)
print("Standard deviation:", scaler.scale_)

# Transform the data using the fitted scaler
scaled_data = scaler.transform(data)
print("Scaled data:", scaled_data)

# Optionally, fit and transform can be done in one step
scaled_data_direct = scaler.fit_transform(data)
print("Directly scaled data:", scaled_data_direct)
# Out:
# Mean: [65.  5.]
# Standard deviation: [11.18033989  2.23606798]
# Scaled data: [[-1.34164079 -1.34164079]
#  [-0.4472136  -0.4472136 ]
#  [ 0.4472136   0.4472136 ]
#  [ 1.34164079  1.34164079]]
# Directly scaled data: [[-1.34164079 -1.34164079]
#  [-0.4472136  -0.4472136 ]
#  [ 0.4472136   0.4472136 ]
#  [ 1.34164079  1.34164079]]

# %%
from sklearn.preprocessing import StandardScaler # fit vs transform vs fit_transform
scaler = StandardScaler()
scaler.fit(xtrain)
xtrain = scaler.transform(xtrain)
xtest = scaler.transform(xtest)

# %%
xtrain
# Out:
# array([[ 1.53003874e+00, -8.86292904e-01, -1.16598019e+00],
#        [ 3.41038651e-01, -1.73144262e-01, -4.09601321e-01],
#        [-5.20208901e-01, -4.20003407e-01,  3.95263370e-01],
#        [-1.58600275e+00,  7.93720724e-01,  1.71892638e+00],
#        [ 1.60659408e+00, -1.33201081e+00, -1.06415995e+00],
#        [-1.63863454e+00, -5.16004186e-01, -3.95055573e-01],
#        [ 1.64128322e+00,  2.86288037e-01, -1.38901498e+00],
#        [-1.64700778e+00, -7.83434927e-01, -3.41721166e-01],
#        [-2.64226989e-01, -1.27715322e+00, -1.02537129e+00],
#        [-1.56447156e+00,  1.06115147e+00, -1.02537129e+00],
#        [-6.69731045e-01, -9.54864889e-01, -1.30174050e+00],
#        [-9.11358830e-01, -1.61315594e+00, -1.03021988e+00],
#        [ 3.82904851e-01, -3.72003018e-01, -2.35052352e-01],
#        [ 2.46540656e-01,  6.77148350e-01,  4.00111952e-01],
#        [-3.67098225e-01,  9.17150297e-01,  2.36378785e+00],
#        [ 6.36494408e-01, -2.00573056e-01, -9.57491140e-01],
# ...

# %% [markdown]
# Training the model

# %%
lm = LinearRegression()
lm.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %% [markdown]
# Checking the intercept and the coefficients

# %%
print(lm.intercept_)
print(lm.coef_)
# Out:
# 14.497142857142858
# [3.68334078 2.90625242 0.14194772]

# %% [markdown]
# Prediction

# %%
preds_train = lm.predict(xtrain)
preds_test = lm.predict(xtest)

# %% [markdown]
# Assessing the model performance through various metrics

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
print(f"RMSE for train data is : {np.sqrt(mean_squared_error(ytrain,preds_train))}")
print(f"R2 for train data is {r2_score(ytrain,preds_train)}")
print(f"RMSE for test data is : {np.sqrt(mean_squared_error(ytest,preds_test))}")
print(f"R2 for test data is {r2_score(ytest,preds_test)}")
# Out:
# RMSE for train data is : 1.5745968305905444
# R2 for train data is 0.9055159502227753
# RMSE for test data is : 1.9485372043446387
# R2 for test data is 0.8609466508230368

# %% [markdown]
# Note: Now draw a comparison between the simple linear regression model and the multiple linear regression model.
#
# The scale of the target variable relative scale: the magnitude of the RMSE should be considered in relation to the scale of the dependent variables (target ). For instance, an RMSE of 2.995 might be very small if the target variable ranges 100 to 1000 but significant if the target ranges from 0 to 5.
# Multiple Linear Regression using statsmodels¶

# %% [markdown]
# # Multiple Linear Regression using statsmodels

# %%
import statsmodels.api as sm
xtrain = sm.add_constant(xtrain)
model = sm.OLS(ytrain,xtrain).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.906
# Model:                            OLS   Adj. R-squared:                  0.903
# Method:                 Least Squares   F-statistic:                     434.5
# Date:                Tue, 21 May 2024   Prob (F-statistic):           1.88e-69
# Time:                        08:58:21   Log-Likelihood:                -262.21
# No. Observations:                 140   AIC:                             532.4
# Df Residuals:                     136   BIC:                             544.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         14.4971      0.135    107.370      0.000      14.230      14.764
# ...

# %%
model.rsquared
# Out:
# 0.9055159502227753
